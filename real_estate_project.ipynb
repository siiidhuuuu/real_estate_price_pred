# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Vaishakh Nambiar/Desktop/Bengaluru_House_Data.csv")

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
data1=data.drop(['area_type','availability','society'],axis='columns')
data1.head()
# Out:
#                    location       size total_sqft  bath  balcony   price
# 0  Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0      1.0   51.00

# %%
data1.isnull().sum()
# Out:
# location        1
# size           16
# total_sqft      0
# bath           73
# balcony       609
# price           0
# dtype: int64

# %%
data2=data1.dropna()

# %%
data2.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# dtype: int64

# %%
data2['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 BHK', '1 RK',
#        '4 BHK', '1 Bedroom', '2 Bedroom', '6 Bedroom', '8 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '11 Bedroom', '43 Bedroom',
#        '14 BHK', '8 BHK', '12 Bedroom', '10 Bedroom', '13 BHK'],
#       dtype=object)

# %%
data2.head()
# Out:
#                    location       size total_sqft  bath  balcony   price
# 0  Electronic City Phase II      2 BHK       1056   2.0      1.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0      3.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0      3.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0      1.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0      1.0   51.00

# %%
data2['bhk'] = data2['size'].apply(lambda x:int(x.split(' ')[0]))
# Out:
# C:\Users\Vaishakh Nambiar\AppData\Local\Temp\ipykernel_8304\1347500727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['bhk'] = data2['size'].apply(lambda x:int(x.split(' ')[0]))

# %%
data2.bhk.unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  7,  5, 11,  9, 27, 43, 14, 12, 10, 13],
#       dtype=int64)

# %%
data2[data2.bhk>10]
# Out:
#                        location        size total_sqft  bath  balcony  price  \
# 459                1 Giri Nagar      11 BHK       5000   9.0      3.0  360.0
# 1718  2Electronic City Phase II      27 BHK       8000  27.0      0.0  230.0
# 1768         1 Ramamurthy Nagar  11 Bedroom       1200  11.0      0.0  170.0
# 3853          1 Annasandrapalya  11 Bedroom       1200   6.0      3.0  150.0
# 4684                Munnekollal  43 Bedroom       2400  40.0      0.0  660.0
# 4916              1Channasandra      14 BHK       1250  15.0      0.0  125.0
# 6533                Mysore Road  12 Bedroom       2232   6.0      2.0  300.0
# 9935              1Hoysalanagar      13 BHK       5425  13.0      0.0  275.0
#
#       bhk
# 459    11
# 1718   27
# 1768   11
# 3853   11
# 4684   43
# 4916   14
# 6533   12
# 9935   13

# %%
data2.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
data2.groupby('total_sqft')['total_sqft'].agg('count')
# Out:
# total_sqft
# 1.25Acres        1
# 1.26Acres        1
# 1000           170
# 1000 - 1285      1
# 10000            2
#               ...
# 995             10
# 996              4
# 997              2
# 998              1
# 999              3
# Name: total_sqft, Length: 1976, dtype: int64

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
data2[~data2['total_sqft'].apply(is_float)].head(10)
# Out:
#                   location       size      total_sqft  bath  balcony    price  \
# 30               Yelahanka      4 BHK     2100 - 2850   4.0      0.0  186.000
# 122                 Hebbal      4 BHK     3067 - 8156   4.0      0.0  477.000
# 137     8th Phase JP Nagar      2 BHK     1042 - 1105   2.0      0.0   54.005
# 165               Sarjapur      2 BHK     1145 - 1340   2.0      0.0   43.490
# 188               KR Puram      2 BHK     1015 - 1540   2.0      0.0   56.800
# 410                Kengeri      1 BHK  34.46Sq. Meter   1.0      0.0   18.500
# 549            Hennur Road      2 BHK     1195 - 1440   2.0      0.0   63.770
# 661              Yelahanka      2 BHK     1120 - 1145   2.0      0.0   48.130
# 672           Bettahalsoor  4 Bedroom     3090 - 5002   4.0      0.0  445.000
# 772  Banashankari Stage VI      2 BHK     1160 - 1195   2.0      0.0   59.935
#
#      bhk
# 30     4
# 122    4
# 137    2
# 165    2
# 188    2
# 410    1
# 549    2
# 661    2
# 672    4
# ...

# %%
def convert_sqft_to_num(x):
    tokens=x.split('-')
    if len(tokens)==2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
data3=data2.copy()
data3['total_sqft']=data3['total_sqft'].apply(convert_sqft_to_num)
data3.head()
# Out:
#                    location       size  total_sqft  bath  balcony   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0      1.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0      3.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0      3.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0      1.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0      1.0   51.00    2

# %%
data3.loc[30]
# Out:
# location      Yelahanka
# size              4 BHK
# total_sqft       2475.0
# bath                4.0
# balcony             0.0
# price             186.0
# bhk                   4
# Name: 30, dtype: object

# %%
data4=data3.copy()
data4['price_per_sqft']=data4['price']*100000/data4['total_sqft']
data4.head()
# Out:
#                    location       size  total_sqft  bath  balcony   price  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0      1.0   39.07
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0      3.0  120.00
# 2               Uttarahalli      3 BHK      1440.0   2.0      3.0   62.00
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0      1.0   95.00
# 4                  Kothanur      2 BHK      1200.0   2.0      1.0   51.00
#
#    bhk  price_per_sqft
# 0    2     3699.810606
# 1    4     4615.384615
# 2    3     4305.555556
# 3    3     6245.890861
# 4    2     4250.000000

# %%
len(data4.location.unique())
# Out:
# 1265

# %%
data4.location = data4.location.apply(lambda x:x.strip())
location_stats = data4.groupby('location')['location'].agg('count').sort_values(ascending=False)
location_stats
# Out:
# location
# Whitefield              515
# Sarjapur  Road          372
# Electronic City         302
# Kanakpura Road          261
# Thanisandra             234
#                        ...
# Kanakapura  Rod           1
# Kanakapura Main Road      1
# Kanakapura Road           1
# Kanakapura Road,          1
# whitefiled                1
# Name: location, Length: 1254, dtype: int64

# %%
location_stats_less_than_10 = location_stats[location_stats<=10]

# %%
location_stats_less_than_10
# Out:
# location
# 1st Block Koramangala    10
# Kalkere                  10
# Basapura                 10
# Kodigehalli              10
# Gunjur Palya             10
#                          ..
# Kanakapura  Rod           1
# Kanakapura Main Road      1
# Kanakapura Road           1
# Kanakapura Road,          1
# whitefiled                1
# Name: location, Length: 1017, dtype: int64

# %%
data4.location = data4.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
len(data4.location.unique())
# Out:
# 238

# %%
data4.head()
# Out:
#                    location       size  total_sqft  bath  balcony   price  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0      1.0   39.07
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0      3.0  120.00
# 2               Uttarahalli      3 BHK      1440.0   2.0      3.0   62.00
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0      1.0   95.00
# 4                  Kothanur      2 BHK      1200.0   2.0      1.0   51.00
#
#    bhk  price_per_sqft
# 0    2     3699.810606
# 1    4     4615.384615
# 2    3     4305.555556
# 3    3     6245.890861
# 4    2     4250.000000

# %%
data4.head(10)
# Out:
#                     location       size  total_sqft  bath  balcony   price  \
# 0   Electronic City Phase II      2 BHK      1056.0   2.0      1.0   39.07
# 1           Chikka Tirupathi  4 Bedroom      2600.0   5.0      3.0  120.00
# 2                Uttarahalli      3 BHK      1440.0   2.0      3.0   62.00
# 3         Lingadheeranahalli      3 BHK      1521.0   3.0      1.0   95.00
# 4                   Kothanur      2 BHK      1200.0   2.0      1.0   51.00
# 5                 Whitefield      2 BHK      1170.0   2.0      1.0   38.00
# 8               Marathahalli      3 BHK      1310.0   3.0      1.0   63.25
# 10                Whitefield      3 BHK      1800.0   2.0      2.0   70.00
# 11                Whitefield  4 Bedroom      2785.0   5.0      3.0  295.00
# 12        7th Phase JP Nagar      2 BHK      1000.0   2.0      1.0   38.00
#
#     bhk  price_per_sqft
# 0     2     3699.810606
# 1     4     4615.384615
# 2     3     4305.555556
# 3     3     6245.890861
# ...

# %%
data4[data4.total_sqft/data4.bhk<300]
# Out:
#                   location       size  total_sqft  bath  balcony  price  bhk  \
# 58           Murugeshpalya  6 Bedroom      1407.0   4.0      1.0  150.0    6
# 68     Devarachikkanahalli  8 Bedroom      1350.0   7.0      0.0   85.0    8
# 70                   other  3 Bedroom       500.0   3.0      2.0  100.0    3
# 78        Kaval Byrasandra      2 BHK       460.0   1.0      0.0   22.0    2
# 89            Rajaji Nagar  6 Bedroom       710.0   6.0      3.0  160.0    6
# ...                    ...        ...         ...   ...      ...    ...  ...
# 13219              Laggere  7 Bedroom      1590.0   9.0      3.0  132.0    7
# 13221                other  9 Bedroom      1178.0   9.0      1.0   75.0    9
# 13281      Margondanahalli  5 Bedroom      1375.0   5.0      1.0  125.0    5
# 13303       Vidyaranyapura  5 Bedroom       774.0   5.0      3.0   70.0    5
# 13311     Ramamurthy Nagar  7 Bedroom      1500.0   9.0      2.0  250.0    7
#
#        price_per_sqft
# ...

# %%
data4.shape
# Out:
# (12710, 8)

# %%
data5 = data4[~(data4.total_sqft/data4.bhk<300)]
data5.shape
# Out:
# (12055, 8)

# %%
data5.price_per_sqft.describe()
# Out:
# count     12013.000000
# mean       6206.082347
# std        3985.518807
# min         267.829813
# 25%        4199.363057
# 50%        5252.525253
# 75%        6823.529412
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
#outlier removal from price_per_sqft
def remove_outliers(df):
    out=pd.DataFrame()
    for key,subdf in df.groupby('location'):
        m=np.mean(subdf.price_per_sqft)
        sd=np.std(subdf.price_per_sqft)
        sort=subdf[(subdf.price_per_sqft>(m-sd)) & (subdf.price_per_sqft<(m+sd))]
        out=pd.concat([out,sort],ignore_index=True)
    return out

data6 = remove_outliers(data5)
data6.shape
# Out:
# (9848, 8)

# %%
data6.head()
# Out:
#               location   size  total_sqft  bath  balcony  price  bhk  \
# 0  1st Block Jayanagar  4 BHK      2850.0   4.0      1.0  428.0    4
# 1  1st Block Jayanagar  3 BHK      1630.0   3.0      2.0  194.0    3
# 2  1st Block Jayanagar  3 BHK      1875.0   2.0      3.0  235.0    3
# 3  1st Block Jayanagar  3 BHK      1200.0   2.0      0.0  130.0    3
# 4  1st Block Jayanagar  2 BHK      1235.0   2.0      2.0  148.0    2
#
#    price_per_sqft
# 0    15017.543860
# 1    11901.840491
# 2    12533.333333
# 3    10833.333333
# 4    11983.805668

# %%
def remove_bhk_outlier(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk]={
                'mean': np.mean(bhk_df.price_per_sqft),
                'std' : np.std(bhk_df.price_per_sqft),
                'count' : bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats=bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

data7 = remove_bhk_outlier(data6)
data7.shape
# Out:
# (7025, 8)

# %%
plt.hist(data7.price_per_sqft,rwidth = 0.8)
plt.xlabel("price per square feet")
plt.ylabel("count")
plt.title("number of properties in price per square feet")
# Out:
# Text(0.5, 1.0, 'number of properties in price per square feet')

# %%
data7.head()
# Out:
#               location   size  total_sqft  bath  balcony  price  bhk  \
# 0  1st Block Jayanagar  4 BHK      2850.0   4.0      1.0  428.0    4
# 1  1st Block Jayanagar  3 BHK      1630.0   3.0      2.0  194.0    3
# 2  1st Block Jayanagar  3 BHK      1875.0   2.0      3.0  235.0    3
# 3  1st Block Jayanagar  3 BHK      1200.0   2.0      0.0  130.0    3
# 4  1st Block Jayanagar  2 BHK      1235.0   2.0      2.0  148.0    2
#
#    price_per_sqft
# 0    15017.543860
# 1    11901.840491
# 2    12533.333333
# 3    10833.333333
# 4    11983.805668

# %%
data7.bath.unique()
# Out:
# array([ 4.,  3.,  2.,  8.,  1.,  5.,  6.,  7.,  9., 13.])

# %%
data7.shape
# Out:
# (7025, 8)

# %%
data7[data7.bath>=data7.bhk+2]
# Out:
#                   location       size  total_sqft  bath  balcony  price  bhk  \
# 33    2nd Stage Nagarbhavi  6 Bedroom      3000.0   8.0      3.0  451.0    6
# 34    2nd Stage Nagarbhavi  6 Bedroom      2400.0   8.0      3.0  450.0    6
# 506                Arekere      4 BHK      2710.0   6.0      2.0  142.0    4
# 553          BTM 2nd Stage  3 Bedroom      1260.0   5.0      1.0  185.0    3
# 785           Bannerghatta      4 BHK      3012.0   6.0      2.0  250.0    4
# ...                    ...        ...         ...   ...      ...    ...  ...
# 9538                 other      4 BHK      6652.0   6.0      1.0  510.0    4
# 9655                 other      2 BHK       600.0   4.0      1.0   70.0    2
# 9704                 other  3 Bedroom      5656.0   5.0      0.0  499.0    3
# 9811                 other      4 BHK      6652.0   6.0      1.0  660.0    4
# 9818                 other  4 Bedroom      6688.0   6.0      1.0  700.0    4
#
#       price_per_sqft
# 33      15033.333333
# ...

# %%
data8 = data7[~(data7.bath>=data7.bhk+2)]

# %%
data8.shape
# Out:
# (6958, 8)

# %%
7025-67
# Out:
# 6958

# %%
data9 = data8.drop(['size','price_per_sqft'],axis='columns')
data9.head()
# Out:
#               location  total_sqft  bath  balcony  price  bhk
# 0  1st Block Jayanagar      2850.0   4.0      1.0  428.0    4
# 1  1st Block Jayanagar      1630.0   3.0      2.0  194.0    3
# 2  1st Block Jayanagar      1875.0   2.0      3.0  235.0    3
# 3  1st Block Jayanagar      1200.0   2.0      0.0  130.0    3
# 4  1st Block Jayanagar      1235.0   2.0      2.0  148.0    2

# %%
pd.get_dummies(data9.location)
# Out:
#       1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                    True               False                      False
# 1                    True               False                      False
# 2                    True               False                      False
# 3                    True               False                      False
# 4                    True               False                      False
# ...                   ...                 ...                        ...
# 9838                False               False                      False
# 9840                False               False                      False
# 9841                False               False                      False
# 9844                False               False                      False
# 9845                False               False                      False
#
#       2nd Stage Nagarbhavi  5th Phase JP Nagar  6th Phase JP Nagar  \
# ...

# %%
dummies = pd.get_dummies(data9.location)
dummies.head()
# Out:
#    1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                 True               False                      False
# 1                 True               False                      False
# 2                 True               False                      False
# 3                 True               False                      False
# 4                 True               False                      False
#
#    2nd Stage Nagarbhavi  5th Phase JP Nagar  6th Phase JP Nagar  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    7th Phase JP Nagar  8th Phase JP Nagar  9th Phase JP Nagar  AECS Layout  \
# 0               False               False               False        False
# ...

# %%
data10 = pd.concat([data9,dummies.drop('other',axis='columns')],axis='columns')
data10.head()
# Out:
#               location  total_sqft  bath  balcony  price  bhk  \
# 0  1st Block Jayanagar      2850.0   4.0      1.0  428.0    4
# 1  1st Block Jayanagar      1630.0   3.0      2.0  194.0    3
# 2  1st Block Jayanagar      1875.0   2.0      3.0  235.0    3
# 3  1st Block Jayanagar      1200.0   2.0      0.0  130.0    3
# 4  1st Block Jayanagar      1235.0   2.0      2.0  148.0    2
#
#    1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                 True               False                      False
# 1                 True               False                      False
# 2                 True               False                      False
# 3                 True               False                      False
# 4                 True               False                      False
#
#    2nd Stage Nagarbhavi  ...  Vijayanagar  Vishveshwarya Layout  \
# 0                 False  ...        False                 False
# ...

# %%
data11 = data10.drop('location',axis='columns')
data11.head()
# Out:
#    total_sqft  bath  balcony  price  bhk  1st Block Jayanagar  \
# 0      2850.0   4.0      1.0  428.0    4                 True
# 1      1630.0   3.0      2.0  194.0    3                 True
# 2      1875.0   2.0      3.0  235.0    3                 True
# 3      1200.0   2.0      0.0  130.0    3                 True
# 4      1235.0   2.0      2.0  148.0    2                 True
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0               False                      False                 False
# 1               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
#
#    5th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# 0               False  ...        False                 False
# ...

# %%
data11.shape
# Out:
# (6958, 242)

# %%
x=data11.drop('price',axis='columns')
x.head()
# Out:
#    total_sqft  bath  balcony  bhk  1st Block Jayanagar  1st Phase JP Nagar  \
# 0      2850.0   4.0      1.0    4                 True               False
# 1      1630.0   3.0      2.0    3                 True               False
# 2      1875.0   2.0      3.0    3                 True               False
# 3      1200.0   2.0      0.0    3                 True               False
# 4      1235.0   2.0      2.0    2                 True               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Phase JP Nagar  \
# 0                      False                 False               False
# 1                      False                 False               False
# 2                      False                 False               False
# 3                      False                 False               False
# 4                      False                 False               False
#
#    6th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# ...

# %%
y=data11.price
y.head()
# Out:
# 0    428.0
# 1    194.0
# 2    235.0
# 3    130.0
# 4    148.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x_train,y_train)
lr_clf.score(x_test,y_test)
# Out:
# 0.8584587986234888

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(),x,y,cv=cv)
# Out:
# array([0.8773143 , 0.84355571, 0.78319592, 0.89718661, 0.8720526 ])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

def find_best_model_using_gridsearchcv(x,y):
    algos = {
         'linear_regression': {
            'model': Pipeline([
                ('scaler', StandardScaler()),
                ('regressor', LinearRegression())
            ]),
            'params': {
                'regressor__fit_intercept': [True, False]
            }
        },
        'lasso' : {
            'model' : Lasso(),
            'params' : {
                'alpha' : [1,2],
                'selection' : ['random', 'cyclic']
            }
        },
        'decision_tree' : {
            'model' : DecisionTreeRegressor(),
            'params' : {
                'criterion' : ['mse', 'friedman_mse'],
                'splitter' : ['best', 'random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'],config['params'],cv=cv, return_train_score=False)
        gs.fit(x,y)
        scores.append({
        'model' : algo_name,
        'best_score' : gs.best_score_,
        'best_params' : gs.best_params_
        })
    return pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\anaconda\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "D:\anaconda\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "D:\anaconda\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
# ...

# %%
x.columns
# Out:
# Index(['total_sqft', 'bath', 'balcony', 'bhk', '1st Block Jayanagar',
#        '1st Phase JP Nagar', '2nd Phase Judicial Layout',
#        '2nd Stage Nagarbhavi', '5th Phase JP Nagar', '6th Phase JP Nagar',
#        ...
#        'Vijayanagar', 'Vishveshwarya Layout', 'Vishwapriya Layout',
#        'Vittasandra', 'Whitefield', 'Yelachenahalli', 'Yelahanka',
#        'Yelahanka New Town', 'Yelenahalli', 'Yeshwanthpur'],
#       dtype='object', length=241)

# %%
def predict_price(location, sqft, bath, bhk, balcony, df11, lr_clf):
    # Define x from the DataFrame without the target column 'price'
    x = df11.drop('price', axis=1)
    
    try:
        # Find the index of the location column
        loc_index = np.where(x.columns == location)[0][0]
    except IndexError:
        # Handle the case where location is not found
        loc_index = -1

    # Create an array of zeros with the same length as the number of columns
    x_pred = np.zeros(len(x.columns))
    x_pred[0] = sqft
    x_pred[1] = bath
    x_pred[2] = bhk
    x_pred[3] = balcony
    if loc_index >= 0:
        x_pred[loc_index] = 1

    # Predict the price using the trained model
    return lr_clf.predict([x_pred])[0]

# Example of how to call the function
# Assuming 'df12' is your DataFrame and 'lr_clf' is your trained model
# Replace '1st Phase JP Nagar', 2000, 3, 4, 2 with actual values
predict_price('Yelahanka New Town', 2000, 4, 10, 2, data11, lr_clf)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 138.29292297323775
